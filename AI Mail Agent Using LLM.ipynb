# %% [markdown]
# ## List of Products

# %%
company_product_list = [
  {
    "laptop_company": "Quantum Computing Technologies",
    "laptop_model": "QuantumLynx X7",
    "laptop_specs_processor": "QuantumCore i9_20000X",
    "laptop_specs_RAM": "32GB DDR5 QuantumSpeed",
    "laptop_specs_storage": "2TB QuantumFlash SSD",
    "laptop_specs_graphics_card": "NVIDIA QuantumForce RTX 4080",
    "laptop_specs_display": "15.6_inch QuantumVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh QuantumCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb QuantumNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "QuantumConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "QuantumLink 5.2",
    "laptop_specs_operating_system": "QuantumOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 1800
  },
  {
    "laptop_company": "Nebula Electronics",
    "laptop_model": "NebulaStar Epsilon 2025",
    "laptop_specs_processor": "NebulaCore i7_15000H",
    "laptop_specs_RAM": "16GB DDR4 NebulaBoost",
    "laptop_specs_storage": "1TB NebulaFlash SSD",
    "laptop_specs_graphics_card": "AMD NebulaGlow RX 6700M",
    "laptop_specs_display": "17.3_inch NebulaView Full HD",
    "laptop_specs_battery": "80Wh NebulaPower Lithium_Ion",
    "laptop_specs_ports_USB": "3 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.0",
    "laptop_specs_ports_Ethernet": "1 x Gigabit NebulaNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NebulaConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NebulaLink 5.1",
    "laptop_specs_operating_system": "NebulaOS 5.0",
    "laptop_specs_weight": "5.2 lbs (2.36 kg)",
    "laptop_specs_dimensions": "16.3 x 11.1 x 0.9 inches (41.4 x 28.2 x 2.3 cm)",
    "Price": 1300
  },
  {
    "laptop_company": "Aether Computing",
    "laptop_model": "AetherBook Pro X3",
    "laptop_specs_processor": "AetherCore i5_10000U",
    "laptop_specs_RAM": "8GB DDR4 AetherSpeed",
    "laptop_specs_storage": "512GB AetherDrive SSD",
    "laptop_specs_graphics_card": "Intel AetherGraphics Xe",
    "laptop_specs_display": "14_inch AetherView Full HD",
    "laptop_specs_battery": "60Wh AetherCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "2 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 1.4",
    "laptop_specs_ports_Ethernet": "1 x Gigabit AetherNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "AetherConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "AetherLink 5.0",
    "laptop_specs_operating_system": "AetherOS 8",
    "laptop_specs_weight": "3.1 lbs (1.41 kg)",
    "laptop_specs_dimensions": "13.9 x 9.5 x 0.6 inches (35.3 x 24.1 x 1.5 cm)",
    "Price": 800
  },
  {
    "laptop_company": "Infinity Devices",
    "laptop_model": "InfinityEdge Pro 15",
    "laptop_specs_processor": "InfinityCore i7_18000H",
    "laptop_specs_RAM": "16GB DDR4 InfinityBoost",
    "laptop_specs_storage": "1TB InfinityFlash SSD",
    "laptop_specs_graphics_card": "NVIDIA InfinityForce GTX 3070",
    "laptop_specs_display": "15.6_inch InfinityVision Full HD",
    "laptop_specs_battery": "70Wh InfinityCharge Lithium_Ion",
    "laptop_specs_ports_USB": "3 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.0",
    "laptop_specs_ports_Ethernet": "1 x Gigabit InfinityNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "InfinityConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "InfinityLink 5.0",
    "laptop_specs_operating_system": "InfinityOS 11",
    "laptop_specs_weight": "4.0 lbs (1.81 kg)",
    "laptop_specs_dimensions": "14.1 x 9.3 x 0.7 inches (35.8 x 23.6 x 1.78 cm)",
    "Price": 800
  },
  {
    "laptop_company": "Techtronics",
    "laptop_model": "TechBook 3000X",
    "laptop_specs_processor": "TechCore i5_12000U",
    "laptop_specs_RAM": "16GB DDR4 TechSpeed",
    "laptop_specs_storage": "512GB TechDrive SSD",
    "laptop_specs_graphics_card": "Intel TechGraphics Xe",
    "laptop_specs_display": "13.3_inch TechView Full HD",
    "laptop_specs_battery": "65Wh TechCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "2 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 1.4",
    "laptop_specs_ports_Ethernet": "1 x Gigabit TechNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "TechConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "TechLink 5.1",
    "laptop_specs_operating_system": "TechOS 9",
    "laptop_specs_weight": "2.9 lbs (1.32 kg)",
    "laptop_specs_dimensions": "12.1 x 8.4 x 0.6 inches (30.7 x 21.3 x 1.5 cm)",
    "Price": 1600
  },
  {
    "laptop_company": "Eclipse Computing",
    "laptop_model": "EclipseBook X1",
    "laptop_specs_processor": "EclipseCore i7_17000H",
    "laptop_specs_RAM": "16GB DDR4 EclipseBoost",
    "laptop_specs_storage": "1TB EclipseFlash SSD",
    "laptop_specs_graphics_card": "NVIDIA EclipseForce GTX 3060",
    "laptop_specs_display": "14_inch EclipseView Full HD",
    "laptop_specs_battery": "75Wh EclipseCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "3 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.0",
    "laptop_specs_ports_Ethernet": "1 x Gigabit EclipseNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "EclipseConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "EclipseLink 5.0",
    "laptop_specs_operating_system": "EclipseOS 10",
    "laptop_specs_weight": "3.3 lbs (1.5 kg)",
    "laptop_specs_dimensions": "13.8 x 9.6 x 0.8 inches (35.1 x 24.4 x 2.03 cm)",
    "Price": 300
  },
  {
    "laptop_company": "Nova Technologies",
    "laptop_model": "NovaBook Pro 17",
    "laptop_specs_processor": "NovaCore i7_16000H",
    "laptop_specs_RAM": "16GB DDR4 NovaBoost",
    "laptop_specs_storage": "1TB NovaFlash SSD",
    "laptop_specs_graphics_card": "NVIDIA NovaForce RTX 3060",
    "laptop_specs_display": "17.3_inch NovaView Full HD",
    "laptop_specs_battery": "80Wh NovaCharge Lithium_Ion",
    "laptop_specs_ports_USB": "3 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.0",
    "laptop_specs_ports_Ethernet": "1 x Gigabit NovaNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NovaConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NovaLink 5.0",
    "laptop_specs_operating_system": "NovaOS 7",
    "laptop_specs_weight": "5.0 lbs (2.27 kg)",
    "laptop_specs_dimensions": "16.4 x 11.0 x 0.8 inches (41.6 x 27.9 x 2.03 cm)",
    "Price": 1600
  },
  {
    "laptop_company": "Galaxy Computing",
    "laptop_model": "GalaxyBook Plus",
    "laptop_specs_processor": "GalaxyCore i5_11000U",
    "laptop_specs_RAM": "8GB DDR4 GalaxyBoost",
    "laptop_specs_storage": "256GB GalaxyDrive SSD",
    "laptop_specs_graphics_card": "Intel GalaxyGraphics Xe",
    "laptop_specs_display": "13.3_inch GalaxyView Full HD",
    "laptop_specs_battery": "60Wh GalaxyCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "2 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 1.4",
    "laptop_specs_ports_Ethernet": "1 x Gigabit GalaxyNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "GalaxyConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "GalaxyLink 5.1",
    "laptop_specs_operating_system": "GalaxyOS 6",
    "laptop_specs_weight": "2.8 lbs (1.27 kg)",
    "laptop_specs_dimensions": "12.0 x 8.1 x 0.6 inches (30.5 x 20.6 x 1.5 cm)",
    "Price": 1800
  },
  {
    "laptop_company": "Orbit Computing",
    "laptop_model": "OrbitBook Pro 14",
    "laptop_specs_processor": "OrbitCore i7_14000H",
    "laptop_specs_RAM": "16GB DDR4 OrbitBoost",
    "laptop_specs_storage": "1TB OrbitFlash SSD",
    "laptop_specs_graphics_card": "NVIDIA OrbitForce GTX 3050",
    "laptop_specs_display": "14_inch OrbitView Full HD",
    "laptop_specs_battery": "70Wh OrbitCharge Lithium_Ion",
    "laptop_specs_ports_USB": "3 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.0",
    "laptop_specs_ports_Ethernet": "1 x Gigabit OrbitNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "OrbitConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "OrbitLink 5.0",
    "laptop_specs_operating_system": "OrbitOS 8",
    "laptop_specs_weight": "3.2 lbs (1.45 kg)",
    "laptop_specs_dimensions": "13.9 x 9.4 x 0.7 inches (35.3 x 23.9 x 1.78 cm)",
    "Price": 1000
  },
  {
    "laptop_company": "Stellar Computing",
    "laptop_model": "StellarBook Pro 13",
    "laptop_specs_processor": "StellarCore i5_13000U",
    "laptop_specs_RAM": "8GB DDR4 StellarBoost",
    "laptop_specs_storage": "512GB StellarDrive SSD",
    "laptop_specs_graphics_card": "Intel StellarGraphics Xe",
    "laptop_specs_display": "13.3_inch StellarView Full HD",
    "laptop_specs_battery": "65Wh StellarCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "2 x USB 3.2, 1 x USB_C",
    "laptop_specs_ports_HDMI": "1 x HDMI 1.4",
    "laptop_specs_ports_Ethernet": "1 x Gigabit StellarNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "StellarConnect Wi_Fi 6 802.11ax",
    "laptop_specs_wireless_Bluetooth": "StellarLink 5.1",
    "laptop_specs_operating_system": "StellarOS 7",
    "laptop_specs_weight": "2.7 lbs (1.23 kg)",
    "laptop_specs_dimensions": "12.0 x 8.2 x 0.6 inches (30.5 x 20.8 x 1.5 cm)",
    "Price": 1300
  },
  {
    "laptop_company": "NeuroComputing Solutions",
    "laptop_model": "NeuroBook Pro X",
    "laptop_specs_processor": "NeuroCore i9_22000X",
    "laptop_specs_RAM": "32GB NeuroRAM Ultra",
    "laptop_specs_storage": "2TB NeuroDrive SSD",
    "laptop_specs_graphics_card": "NeuroGraphics RTX 5080",
    "laptop_specs_display": "16_inch NeuroVision 4K Ultra_HD",
    "laptop_specs_battery": "110Wh NeuroCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb NeuroNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NeuroConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NeuroLink 5.2",
    "laptop_specs_operating_system": "NeuroOS 15",
    "laptop_specs_weight": "3.6 lbs (1.63 kg)",
    "laptop_specs_dimensions": "14.3 x 9.8 x 0.7 inches (36.3 x 24.9 x 1.78 cm)",
    "Price": 1700
  },
  {
    "laptop_company": "HyperTech Innovations",
    "laptop_model": "HyperBook Pro X2",
    "laptop_specs_processor": "HyperCore i9_22000X",
    "laptop_specs_RAM": "32GB HyperRAM Pro",
    "laptop_specs_storage": "2TB HyperDrive SSD",
    "laptop_specs_graphics_card": "HyperGraphics RTX 5080",
    "laptop_specs_display": "16.5_inch HyperVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh HyperCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb HyperNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "HyperConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "HyperLink 5.2",
    "laptop_specs_operating_system": "HyperOS 14",
    "laptop_specs_weight": "3.8 lbs (1.72 kg)",
    "laptop_specs_dimensions": "14.5 x 10.0 x 0.8 inches (36.8 x 25.4 x 2.03 cm)",
    "Price": 1100
  },
  {
    "laptop_company": "AI Dynamics Corporation",
    "laptop_model": "AIBrain X9",
    "laptop_specs_processor": "AICore i9_22000X",
    "laptop_specs_RAM": "32GB AIRM Ultra",
    "laptop_specs_storage": "2TB AIDrive SSD",
    "laptop_specs_graphics_card": "AIGraphics RTX 5080",
    "laptop_specs_display": "16_inch AIVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh AICharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb AINet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "AIConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "AILink 5.2",
    "laptop_specs_operating_system": "AiOS 16",
    "laptop_specs_weight": "3.7 lbs (1.68 kg)",
    "laptop_specs_dimensions": "14.4 x 9.9 x 0.7 inches (36.6 x 25.1 x 1.78 cm)",
    "Price": 1200
  },
  {
    "laptop_company": "NeuralTech Solutions",
    "laptop_model": "NeuralBook Pro X3",
    "laptop_specs_processor": "NeuralCore i9_22000X",
    "laptop_specs_RAM": "32GB NeuralRAM Pro",
    "laptop_specs_storage": "2TB NeuralDrive SSD",
    "laptop_specs_graphics_card": "NeuralGraphics RTX 5080",
    "laptop_specs_display": "16.1_inch NeuralVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh NeuralCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb NeuralNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NeuralConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NeuralLink 5.2",
    "laptop_specs_operating_system": "NeuralOS 14",
    "laptop_specs_weight": "3.6 lbs (1.63 kg)",
    "laptop_specs_dimensions": "14.2 x 9.7 x 0.7 inches (36.1 x 24.6 x 1.78 cm)",
    "Price": 2300
  },
  {
    "laptop_company": "QuantaTech Innovations",
    "laptop_model": "QuantaBook Pro X",
    "laptop_specs_processor": "QuantaCore i9_22000X",
    "laptop_specs_RAM": "32GB QuantaRAM Pro",
    "laptop_specs_storage": "2TB QuantaDrive SSD",
    "laptop_specs_graphics_card": "QuantaGraphics RTX 5080",
    "laptop_specs_display": "16_inch QuantaVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh QuantaCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb QuantaNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "QuantaConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "QuantaLink 5.2",
    "laptop_specs_operating_system": "QuantaOS 13",
    "laptop_specs_weight": "3.6 lbs (1.63 kg)",
    "laptop_specs_dimensions": "14.3 x 9.8 x 0.7 inches (36.3 x 24.9 x 1.78 cm)",
    "Price": 1200
  },
  {
    "laptop_company": "Mindwave Technologies",
    "laptop_model": "MindBook Pro X",
    "laptop_specs_processor": "MindCore i9_22000X",
    "laptop_specs_RAM": "32GB MindRAM Pro",
    "laptop_specs_storage": "2TB MindDrive SSD",
    "laptop_specs_graphics_card": "MindGraphics RTX 5080",
    "laptop_specs_display": "16.2_inch MindVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh MindCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb MindNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "MindConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "MindLink 5.2",
    "laptop_specs_operating_system": "MindOS 14",
    "laptop_specs_weight": "3.6 lbs (1.63 kg)",
    "laptop_specs_dimensions": "14.4 x 9.9 x 0.7 inches (36.6 x 25.1 x 1.78 cm)",
    "Price": 1500
  },
  {
    "laptop_company": "Neural Dynamics Inc.",
    "laptop_model": "NeuroBook Pro X2",
    "laptop_specs_processor": "NeuroCore i9_22000X",
    "laptop_specs_RAM": "32GB NeuroRAM Pro",
    "laptop_specs_storage": "2TB NeuroDrive SSD",
    "laptop_specs_graphics_card": "NeuroGraphics RTX 5080",
    "laptop_specs_display": "16.3_inch NeuroVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh NeuroCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb NeuroNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NeuroConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NeuroLink 5.2",
    "laptop_specs_operating_system": "NeuroOS 15",
    "laptop_specs_weight": "3.7 lbs (1.68 kg)",
    "laptop_specs_dimensions": "14.5 x 10.0 x 0.7 inches (36.8 x 25.4 x 1.78 cm)",
    "Price": 500
  },
  {
    "laptop_company": "Brainwave Technologies",
    "laptop_model": "BrainBook Pro X",
    "laptop_specs_processor": "BrainCore i9_22000X",
    "laptop_specs_RAM": "32GB BrainRAM Pro",
    "laptop_specs_storage": "2TB BrainDrive SSD",
    "laptop_specs_graphics_card": "BrainGraphics RTX 5080",
    "laptop_specs_display": "16.4_inch BrainVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh BrainCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb BrainNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "BrainConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "BrainLink 5.2",
    "laptop_specs_operating_system": "BrainOS 14",
    "laptop_specs_weight": "3.7 lbs (1.68 kg)",
    "laptop_specs_dimensions": "14.6 x 10.1 x 0.7 inches (37.1 x 25.7 x 1.78 cm)",
    "Price": 1000
  },
  {
    "laptop_company": "Quantum Tech Corporation",
    "laptop_model": "QuantumBook Pro X",
    "laptop_specs_processor": "QuantumCore i9_22000X",
    "laptop_specs_RAM": "32GB QuantumRAM Pro",
    "laptop_specs_storage": "2TB QuantumDrive SSD",
    "laptop_specs_graphics_card": "QuantumGraphics RTX 5080",
    "laptop_specs_display": "16.5_inch QuantumVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh QuantumCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb QuantumNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "QuantumConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "QuantumLink 5.2",
    "laptop_specs_operating_system": "QuantumOS 15",
    "laptop_specs_weight": "3.6 lbs (1.63 kg)",
    "laptop_specs_dimensions": "14.7 x 10.2 x 0.7 inches (37.3 x 25.9 x 1.78 cm)",
    "Price": 2400
  },
  {
    "laptop_company": "Neural Systems Ltd.",
    "laptop_model": "NeuralBook Pro X",
    "laptop_specs_processor": "NeuralCore i9_22000X",
    "laptop_specs_RAM": "32GB NeuralRAM Pro",
    "laptop_specs_storage": "2TB NeuralDrive SSD",
    "laptop_specs_graphics_card": "NeuralGraphics RTX 5080",
    "laptop_specs_display": "16.6_inch NeuralVision 4K Ultra_HD",
    "laptop_specs_battery": "120Wh NeuralCharge Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb NeuralNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NeuralConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NeuralLink 5.2",
    "laptop_specs_operating_system": "NeuralOS 16",
    "laptop_specs_weight": "3.7 lbs (1.68 kg)",
    "laptop_specs_dimensions": "14.8 x 10.3 x 0.7 inches (37.6 x 26.2 x 1.78 cm)",
    "Price": 1600
  },
  {
    "laptop_company": "Quantum Fusion Technologies",
    "laptop_model": "QuantumFusion X",
    "laptop_specs_processor": "QuantumCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 QuantumSpeed",
    "laptop_specs_storage": "2TB QuantumFusion SSD",
    "laptop_specs_graphics_card": "NVIDIA QuantumForce RTX 4080",
    "laptop_specs_display": "15.6_inch QuantumVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh QuantumCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb QuantumNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "QuantumConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "QuantumLink 5.2",
    "laptop_specs_operating_system": "QuantumOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 1000
  },
  {
    "laptop_company": "Innovative Computing Solutions",
    "laptop_model": "InnoBook Pro X",
    "laptop_specs_processor": "InnoCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 InnoSpeed",
    "laptop_specs_storage": "2TB InnoDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA InnoForce RTX 4080",
    "laptop_specs_display": "15.6_inch InnoVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh InnoCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb InnoNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "InnoConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "InnoLink 5.2",
    "laptop_specs_operating_system": "InnoOS 12",
    "laptop_specs_weight": "3.6 lbs (1.63 kg)",
    "laptop_specs_dimensions": "14.2 x 9.8 x 0.7 inches (36.1 x 24.9 x 1.78 cm)",
    "Price": 1300
  },
  {
    "laptop_company": "FutureTech Innovations",
    "laptop_model": "FutureBook Pro X",
    "laptop_specs_processor": "FutureCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 FutureSpeed",
    "laptop_specs_storage": "2TB FutureDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA FutureForce RTX 4080",
    "laptop_specs_display": "15.6_inch FutureVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh FutureCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb FutureNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "FutureConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "FutureLink 5.2",
    "laptop_specs_operating_system": "FutureOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 600
  },
  {
    "laptop_company": "Quantum Dynamics Ltd.",
    "laptop_model": "QuantumPro X2",
    "laptop_specs_processor": "QuantumCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 QuantumSpeed",
    "laptop_specs_storage": "2TB QuantumDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA QuantumForce RTX 4080",
    "laptop_specs_display": "15.6_inch QuantumVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh QuantumCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb QuantumNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "QuantumConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "QuantumLink 5.2",
    "laptop_specs_operating_system": "QuantumOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 400
  },
  {
    "laptop_company": "Innovative Computing Solutions",
    "laptop_model": "InnoBook Pro X2",
    "laptop_specs_processor": "InnoCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 InnoSpeed",
    "laptop_specs_storage": "2TB InnoDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA InnoForce RTX 4080",
    "laptop_specs_display": "15.6_inch InnoVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh InnoCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb InnoNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "InnoConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "InnoLink 5.2",
    "laptop_specs_operating_system": "InnoOS 12",
    "laptop_specs_weight": "3.6 lbs (1.63 kg)",
    "laptop_specs_dimensions": "14.2 x 9.8 x 0.7 inches (36.1 x 24.9 x 1.78 cm)",
    "Price": 900
  },
  {
    "laptop_company": "FutureTech Innovations",
    "laptop_model": "FutureBook Pro X2",
    "laptop_specs_processor": "FutureCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 FutureSpeed",
    "laptop_specs_storage": "2TB FutureDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA FutureForce RTX 4080",
    "laptop_specs_display": "15.6_inch FutureVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh FutureCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb FutureNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "FutureConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "FutureLink 5.2",
    "laptop_specs_operating_system": "FutureOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 500
  },
  {
    "laptop_company": "NeuroTech Solutions",
    "laptop_model": "NeuroBook Pro X2",
    "laptop_specs_processor": "NeuroCore i7_22000X",
    "laptop_specs_RAM": "32GB DDR5 NeuroSpeed",
    "laptop_specs_storage": "2TB NeuroDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA NeuroForce RTX 4080",
    "laptop_specs_display": "15.6_inch NeuroVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh NeuroCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb NeuroNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NeuroConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NeuroLink 5.2",
    "laptop_specs_operating_system": "NeuroOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 800
  },
  {
    "laptop_company": "AI Innovations Inc.",
    "laptop_model": "AIBrain Pro X",
    "laptop_specs_processor": "AICore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 AISpeed",
    "laptop_specs_storage": "2TB AIDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA AIForce RTX 4080",
    "laptop_specs_display": "15.6_inch AIVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh AICharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb AINet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "AIConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "AILink 5.2",
    "laptop_specs_operating_system": "AiOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 1500
  },
  {
    "laptop_company": "Neural Processing Solutions",
    "laptop_model": "NeuroBook Pro X3",
    "laptop_specs_processor": "NeuroCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 NeuroSpeed",
    "laptop_specs_storage": "2TB NeuroDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA NeuroForce RTX 4080",
    "laptop_specs_display": "15.6_inch NeuroVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh NeuroCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb NeuroNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "NeuroConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "NeuroLink 5.2",
    "laptop_specs_operating_system": "NeuroOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 1000
  },
  {
    "laptop_company": "Brainwave Tech Inc.",
    "laptop_model": "BrainBook Pro X2",
    "laptop_specs_processor": "BrainCore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 BrainSpeed",
    "laptop_specs_storage": "2TB BrainDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA BrainForce RTX 4080",
    "laptop_specs_display": "15.6_inch BrainVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh BrainCharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb BrainNet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "BrainConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "BrainLink 5.2",
    "laptop_specs_operating_system": "BrainOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 200
  },
  {
    "laptop_company": "AI Innovations Inc.",
    "laptop_model": "AIBrain Pro X2",
    "laptop_specs_processor": "AICore i9_22000X",
    "laptop_specs_RAM": "32GB DDR5 AISpeed",
    "laptop_specs_storage": "2TB AIDrive SSD",
    "laptop_specs_graphics_card": "NVIDIA AIForce RTX 4080",
    "laptop_specs_display": "15.6_inch AIVision 4K Ultra_HD",
    "laptop_specs_battery": "100Wh AICharge+ Lithium_Polymer",
    "laptop_specs_ports_USB": "4 x USB 4.0, 2 x Thunderbolt 5",
    "laptop_specs_ports_HDMI": "1 x HDMI 2.1",
    "laptop_specs_ports_Ethernet": "1 x 10Gb AINet",
    "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
    "laptop_specs_wireless_Wi_Fi": "AIConnect 6E Wi_Fi 802.11ax",
    "laptop_specs_wireless_Bluetooth": "AILink 5.2",
    "laptop_specs_operating_system": "AiOS 12",
    "laptop_specs_weight": "3.5 lbs (1.59 kg)",
    "laptop_specs_dimensions": "14.1 x 9.7 x 0.7 inches (35.8 x 24.6 x 1.78 cm)",
    "Price": 500
  }
]

# %% [markdown]
# ## AI Credentials

# %%
import os
from groq_api import api
from groq import Groq
from flask import jsonify
import json
import pandas as pd
client = Groq(api_key=api)

# %% [markdown]
# ## Customer Email

# %% [markdown]
# ## fetch product details from the Customer Email

# %% [markdown]
# ## Generating Mail Based on Product and User Email

# %%
customer_email = f"""Subject: Disappointing Performance and Overpriced: NebulaStar Epsilon 2025 Laptop
Dear customer care,
I hope this email finds you well. I am writing to share my recent experience with the NebulaStar Epsilon 2025 laptop from Nebula Electronics. Unfortunately, my experience with this device has been overwhelmingly disappointing, especially considering its exorbitant price tag of $1300.
First and foremost, let's address the elephant in the room: performance. Despite its promising specifications on paper, including the NebulaCore i7_15000H processor and 16GB DDR4 NebulaBoost RAM, the actual performance of this laptop falls far short of expectations. Tasks that should be handled with ease, such as multitasking or running moderately demanding applications, are met with frustratingly sluggish performance. Even simple tasks like web browsing and document editing feel painfully slow, making productivity a constant struggle.
The inadequacy of the NebulaStar Epsilon 2025 becomes even more apparent when considering its price point. At $1300, one would expect a laptop that delivers exceptional performance and value for money. However, this laptop fails to justify its steep price tag in any aspect. Comparable laptops from other manufacturers offer superior performance at a fraction of the cost, making the NebulaStar Epsilon 2025 a poor investment for anyone seeking value and performance.
In my opinion, based on its subpar performance and unjustifiably high price, the NebulaStar Epsilon 2025 should be priced much lower, ideally in the range of $300. At this price point, it would at least be more reasonable for what it offers in terms of performance and features.
In conclusion, I cannot recommend the NebulaStar Epsilon 2025 to anyone in search of a reliable and capable laptop. Its underwhelming performance and inflated price make it a regrettable purchase that falls short of meeting even basic user expectations.
Thank you for taking the time to read my feedback. Should you have any further questions or require additional information, please do not hesitate to reach out.
Sincerely,
John Doe,
John.Doe@gmail.com"""


def product_category(customer_email):
    delimiter = '####'
    internal_prompt = f"""You will be provided with an email regarding a product which will be delimited by {delimiter}. \
You need to categorize the given email into one of these categories: \
product_inquiry - if the email is regarding any questions about the product, \
product_complaint - if the email is regarding any complaints about the product, \
customer_feedback - if the email is regarding any feedback about the product, \
customer_care - if the email is asking to connect with the customer care service of the company.\n

The response should be a single word only, and that should be the category such as product_inquiry, product_complaint, customer_feedback, or customer_care.
"""
    user_prompt_category = f"""{internal_prompt} {delimiter} {customer_email} {delimiter}"""
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "user", "content": user_prompt_category}
        ],
        model="mixtral-8x7b-32768",
    )

    category_final = chat_completion.choices[0].message.content.strip()
    return category_final

def product_model(customer_email):
    delimiter = '####'
    internal_prompt = f"""You will be provided with an email regarding a product which will be delimited by {delimiter}. \
You need to fetch the product details from the given email. \
From the given email just fetch the model detail and provide back.
"""
    user_prompt_product = f"""{internal_prompt} {delimiter} {customer_email} {delimiter}"""
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "user", "content": user_prompt_product}
        ],
        model="mixtral-8x7b-32768",
    )
    product_detail_final = chat_completion.choices[0].message.content.strip()
    return product_detail_final

def fetch_entire_data(product_detail_final, company_product_list):
    delimiter = '####'
    internal_prompt = f"""You will be provided with the model name of the laptop which is {product_detail_final}. \
You need to check for the full value in the given JSON and just pass the JSON of the given model of the laptop. \
You can use this list to fetch the JSON: {company_product_list}.
"""
    regex_ai = f"""{internal_prompt} """
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "user", "content": regex_ai}
        ],
        model="mixtral-8x7b-32768",
    )
    regex_ai_final = chat_completion.choices[0].message.content.strip()
    return regex_ai_final

def generate_response(category_final, customer_email, regex_ai_final):
    delimiter = '####'
    internal_prompt = f"""The email category which the mail we got from the user belongs to: {category_final}. \
We need to give the response back to the customer email based on: {customer_email}. \
We need to address the mail, write an email to convince the customer that we will be solving their issue or listening to them. \
The data of the product the customer is talking about is this: \
{delimiter}{regex_ai_final}{delimiter}
Our Name is: Jokasda AI who is an ai assistant for automating emails. the name of the company will be the company name of the product.
"""
    generate_mail_prompt = f"""{internal_prompt}"""
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "user", "content": generate_mail_prompt}
        ],
        model="mixtral-8x7b-32768",
    )
    generate_mail_output = chat_completion.choices[0].message.content.strip()
    return generate_mail_output

def ai_to_json(customer_email, gen_mail):
    delimiter = '####'
    internal_prompt = f"""You will be given an email. It will include the name of the person, contact details, product name, and issue. \
Here is the email from the user: {customer_email}.
Based on this email, we are generating this response: {gen_mail}. \
Your task is to provide a JSON list with the following five keys: \
'name', 'contact', 'product detail', 'issue', and 'status'. \
The values for 'name', 'contact', 'product detail', and 'issue' should be extracted from the emails. \
The 'status' value will always be empty. \
The 'issue' should be summarized in only two words.
"""
    json_prompt = f"""{internal_prompt}"""
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "user", "content": json_prompt}
        ],
        model="mixtral-8x7b-32768",
    )
    mail_to_json_output = chat_completion.choices[0].message.content.strip()
    load_json = json.loads(mail_to_json_output)
    df = pd.DataFrame(load_json)
    # Check if the file exists
    if os.path.isfile('logs.xlsx'):
        # Read existing Excel file
        existing_df = pd.read_excel('logs.xlsx', engine='openpyxl')
        # Append the new DataFrame to the existing one
        combined_df = pd.concat([existing_df, df], ignore_index=True)
        # Write the combined DataFrame to the Excel file
        with pd.ExcelWriter('logs.xlsx', mode='w', engine='openpyxl') as writer:
            combined_df.to_excel(writer, index=False)
    else:
        # If the file does not exist, create a new one
        with pd.ExcelWriter('logs.xlsx', mode='w', engine='openpyxl') as writer:
            df.to_excel(writer, index=False)

# Example usage:
customer_email = customer_email
company_product_list = company_product_list

# Step 1: Categorize the email
category_final = product_category(customer_email)
print(category_final)

# Step 2: Extract product model from email
product_detail_final = product_model(customer_email)
print(product_detail_final)

# Step 3: Fetch entire data based on the product model
regex_ai_final = fetch_entire_data(product_detail_final, company_product_list)
print(regex_ai_final)

# Step 4: Generate response based on category, email, and fetched data
gen_mail = generate_response(category_final, customer_email, regex_ai_final)
print(gen_mail)

# Step 5: Generate JSON output
ai_to_json(customer_email, gen_mail)
print(ai_to_json)
# Out:
# product_complaint
# The model detail from the provided email is: NebulaStar Epsilon 2025.
# The model detail provided is: NebulaStar Epsilon 2025. Here is the JSON for this model:
#
# ```json
# {
#   "laptop_company": "Nebula Electronics",
#   "laptop_model": "NebulaStar Epsilon 2025",
#   "laptop_specs_processor": "NebulaCore i7_15000H",
#   "laptop_specs_RAM": "16GB DDR4 NebulaBoost",
#   "laptop_specs_storage": "1TB NebulaFlash SSD",
#   "laptop_specs_graphics_card": "AMD NebulaGlow RX 6700M",
#   "laptop_specs_display": "17.3_inch NebulaView Full HD",
#   "laptop_specs_battery": "80Wh NebulaPower Lithium_Ion",
#   "laptop_specs_ports_USB": "3 x USB 3.2, 1 x USB_C",
#   "laptop_specs_ports_HDMI": "1 x HDMI 2.0",
#   "laptop_specs_ports_Ethernet": "1 x Gigabit NebulaNet",
#   "laptop_specs_ports_Audio": "1 x 3.5mm headphone/microphone combo jack",
#   "laptop_specs_wireless_Wi_Fi": "NebulaConnect Wi_Fi 6 802.11ax",
#   "laptop_specs_wireless_Bluetooth": "NebulaLink 5.1",
# ...

# %%
logs = pd.read_excel('logs.xlsx', engine = 'openpyxl')

# %%
logs
# Out:
#              name                   contact                  product detail  \
# 0  Samir Sengupta  Samir843301003@gmail.com  NebulaStar Epsilon 2025 laptop
# 1        John Doe        John.Doe@gmail.com  NebulaStar Epsilon 2025 laptop
#
#               issue  status
# 0  Poor Performance     NaN
# 1  Poor Performance     NaN
